# %% [markdown]
# <a href="https://colab.research.google.com/github/Dammyjb/Dammyjb/blob/main/Workout_Generator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def fitness_goals():
  goals = ["Lose weight", "Gain weight", "Tone up"]
  name = input("What is your name?: ")

  userinput = input("What is your fitness goal?: ")

  if userinput in goals:
    conf = input(f'{name} wants to {userinput.lower()}?: ').lower()
    if conf == "yes":
       print("Great! We can help you get started!")
    elif conf == "no":
       print("Mind redefining your goals?")
  else:
       print("Goal not found. Please pick one:")
       for g in goals:
        print("-", g)



def exercise_categories():
  exercise = ["Aerobics", "Strength", "Cardio", "Flexibility", "Balance"]

  userinput = input("What type of exercise would you like to do?: ")

  if userinput in exercise:
     print(f"We can help you develop a plan to improve {userinput.lower()}!")
  else:
     print(f"Exercise not found. Please pick one:")
     for e in exercise:
      print("-", i)


def workout_plan():
  pass
fitness_goals()
exercise_categories()
# Out:
# What is your name?: dammy
# What is your fitness goal?: get swole
# Goal not found. Please pick one:
# - Lose weight
# - Gain weight
# - Tone up
# What type of exercise would you like to do?: Strength
# We can help you develop a plan to improve strength!
